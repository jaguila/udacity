# %% [markdown]
# This project is to accurately be able to predict the income level of a donors for a charity. The income levels are helpful in order understand how much money to ask from each donor. We will conduct this prediction using supervised ML models. The first step will be trying to figure out the best model then working on optimizing that model by configuring the best parameters.

# %%
import csv

with open('adult.txt', 'rb') as input_file:
    lines = input_file.readlines()
    newLines = []
    for line in lines:
        newLine = line.strip().split()
        newLines.append( newLine )
testLine=[i[:-1].decode("utf-8") for ii in newLines for i in ii]
test=[testLine[i:i+15] for i in range(0,len(testLine), 15)]
header=["age", "workclass", "fnlwgt", "education", "education-num","marital-status","occupation","relationship","race",
        "sex" ,"capital-gain","capital-loss","hours-per-week","native-country", "income"]
with open('census.csv', 'w',newline='') as test_file:
    file_writer = csv.writer(test_file)
    file_writer.writerow(header)
    file_writer.writerows(test)

# %% [markdown]
# # importing data into pandas and doing some initial exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
from IPython.display import display
# %matplotlib inline

# %%
data=pd.read_csv('census.csv')
data=data.drop(['fnlwgt'],axis=1)
display(data.head())
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country income
# 0             0              40  United-States   <=50
# 1             0              13  United-States   <=50
# 2             0              40  United-States   <=50
# 3             0              40  United-States   <=50
# 4             0              40           Cuba   <=50

# %% [markdown]
# Lets get a initial look at the distribution of our donors based on our training dataset
#
# - The total number of records
# - The number of individuals making more than \$50,000 annually
# - The number of individuals making at most \$50,000 annually
# - The percentage of individuals making more than \$50,000 annually

# %%
print("the total number of records: ", data.iloc[:,0].count())
print("The number of individuals less more than $50,000 annually :",data[data['income']=='<=50'].iloc[:,0].count())
print("The number of individuals more more than $50,000 annually :",data[data['income']=='>50'].iloc[:,0].count())
print("The percentage of individuals making more than $50,000 annually: ", 100.0*data[data['income']=='>50'].iloc[:,0].count()/data.iloc[:,0].count(),"%")
# Out:
# the total number of records:  32561
# The number of individuals less more than $50,000 annually : 24720
# The number of individuals more more than $50,000 annually : 7841
# The percentage of individuals making more than $50,000 annually:  24.080955744602438 %

# %% [markdown]
# Below is the breakdown of the individual features:
# ** Featureset Exploration **
#
# * **age**: continuous.
# * **workclass**: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * **education**: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * **education-num**: continuous.
# * **marital-status**: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * **occupation**: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * **relationship**: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * **race**: Black, White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other.
# * **sex**: Female, Male.
# * **capital-gain**: continuous.
# * **capital-loss**: continuous.
# * **hours-per-week**: continuous.
# * **native-country**: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [raw]
#   fig = pl.figure(figsize = (11,5));
#
#     # Skewed feature plotting
#     for i, feature in enumerate(['capital-gain','capital-loss']):
#         ax = fig.add_subplot(1, 2, i+1)
#         ax.hist(data[feature], bins = 25, color = '#00A0A0')
#         ax.set_title("'%s' Feature Distribution"%(feature), fontsize = 14)
#         ax.set_xlabel("Value")
#         ax.set_ylabel("Number of Records")
#         ax.set_ylim((0, 2000))
#         ax.set_yticks([0, 500, 1000, 1500, 2000])
#         ax.set_yticklabels([0, 500, 1000, 1500, ">2000"])

# %% [markdown]
# ## Let us take a look at the continuous data and see if we need to normalize any of them
#     -we are looking to normalize any data that has a very large standard deviation

# %%
feats_num=[i for i in data if data[i].dtype=='int64']

# %% [markdown]
#     -We will plot the continuous features by count of income bracket occurence and see if there is any normalization we can   conduct

# %%
def plot_feats(feats,df):
    fig=pl.figure(figsize=(20,20))
    display(data[feats].describe())

    fig.subplots_adjust(hspace=0.5)
    for i, x in enumerate(feats):
        i+=1

        ax=fig.add_subplot(3,2,i)
        v=['income',x]
        df_n=pd.DataFrame.copy(df)
        lab=[vv+str(v) for v,vv in enumerate(["group"]*20)]
#         df_n[x]=pd.cut(df_n[x],20,labels=lab)
        
        ndata=df_n.groupby(v).count().reset_index()
#         ndata=df_n
        
        lt50=ndata[ndata['income']=='<=50']
#         display(lt50)
        gt50=ndata[ndata['income']=='>50']
        if x in ['capital-loss', 'capital-gain', 'hours-per-week']:
            ax.set_ylim(0,1000)
            ax.set_yticks([0,250, 500,750, 1000])
#         ax.hist(lt50[x],color='g', bins=20)
#         ax.hist(gt50[x],color='r', bins=20)
#         pl.xticks(x)
#         ax.bar(lt50[x],lt50['workclass'],width=0.25,color='g')
#         ax2 = ax.twinx()
#         ax2.bar(gt50[x],gt50['workclass'],width=0.25,color='g')
        
        ax.plot(lt50[x],lt50['workclass'],color='g')

        ax.plot(gt50[x],gt50['workclass'],color='c')

        ax.set_title('Distribution of %s by Income' %(x))
        ax.legend(['<=50k',">50k"])
    
plot_feats(feats_num, data)
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  32561.000000   32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647      10.080679   1077.648844     87.303830       40.437456
# std       13.640433       2.572720   7385.292085    402.960219       12.347429
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# As we can see capital-gains and capital-loss need to be normalized a bit since the data is very right skewed. Let us conduct a log transformation on this data.

# %%
skewed=['capital-gain','capital-loss']
features_log_x=pd.DataFrame.copy(data)
features_log_x[skewed]=features_log_x[skewed].apply(lambda x:np.log(x+1))

display(features_log_x[skewed].describe())
plot_feats(skewed, features_log_x)
# Out:
#        capital-gain  capital-loss
# count  32561.000000  32561.000000
# mean       0.734621      0.350305
# std        2.454738      1.584581
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       11.512925      8.379539
#        capital-gain  capital-loss
# count  32561.000000  32561.000000
# mean    1077.648844     87.303830
# std     7385.292085    402.960219
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max    99999.000000   4356.000000

# %% [markdown]
#     -In order to ensure that variables are treated evenly we will conduct normalization using minmaxscaler.

# %% [raw]
# # Import sklearn.preprocessing.StandardScaler
# from sklearn.preprocessing import MinMaxScaler
#
# # Initialize a scaler, then apply it to the features
# scaler = MinMaxScaler() # default=(0, 1)
# numerical = ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
#
# features_log_minmax_transform = pd.DataFrame(data = features_log_transformed)
# features_log_minmax_transform[numerical] = scaler.fit_transform(features_log_transformed[numerical])
#
# # Show an example of a record with scaling applied
# display(features_log_minmax_transform.head(n = 5))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()

features_minmax_log=pd.DataFrame.copy(features_log_x)
features_minmax_log[feats_num]=scaler.fit_transform(features_minmax_log[feats_num])

features_minmax_log.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  32561.000000   32561.000000  32561.000000  32561.000000    32561.000000
# mean       0.295639       0.605379      0.063808      0.041805        0.402423
# std        0.186855       0.171515      0.213216      0.189101        0.125994
# min        0.000000       0.000000      0.000000      0.000000        0.000000
# 25%        0.150685       0.533333      0.000000      0.000000        0.397959
# 50%        0.273973       0.600000      0.000000      0.000000        0.397959
# 75%        0.424658       0.733333      0.000000      0.000000        0.448980
# max        1.000000       1.000000      1.000000      1.000000        1.000000

# %% [markdown]
# We will now conduct One-Hot Encoding to turn all categorical variables into numeric for the models and then conduct a test train split to help setup our first models

# %%
from sklearn.cross_validation import train_test_split

feat_final=pd.get_dummies(features_minmax_log.drop('income',axis=1))
Y=features_minmax_log['income'].map({'>50':1, '<=50':0})


X_train, X_test, y_train,y_test=train_test_split(feat_final, Y, test_size=0.2)
# Out:
# C:\Users\dexter.aguila\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Next we will see the distribution of the output variable (Income)to help understand what metric we should be using to rate our model performance

# %%
fig2=pl.figure(figsize=(11,5))
ax2=fig2.add_subplot(1,1,1)
ax2.hist(Y)
ax2.set_xlabel("Income")
ax2.set_ylabel('Count of Income responses')
ax2.set_xticks([0,1])
ax2.set_xticklabels(["<=50k",">50k"])
# Out:
# [<matplotlib.text.Text at 0x13cda4d6c18>,
#  <matplotlib.text.Text at 0x13cda1dddd8>]

# %% [raw]
# Since there is a much larger distribution of >50k vs <50k contributors. Precision (True pos/(True pos + false pos)), recall (True pos/(True pos + false neg)), and F score would be good metrics to use.

# %% [markdown]
# Prior to choosing a ML algorithm let us see if there are any correlations the features and income.

# %%
import seaborn as sns
data2=data.copy()
sns.set(style='ticks')
sns.pairplot(data2, hue='income')

# %%
data2['income']=data2['income'].map({"<=50":0,">50":1})
sns.heatmap(data2.corr(),annot=True)

# %% [raw]
# As we can see there are great correlations between all the variables and income.
#
# I will now try three different algorithms in order to fit the model. They are SVM and two ensembles( adaboost and random
# forests). I chose each for the following reasons
#
# SVM Model is great for parameter tuning and the dataset is a good site for this.
#
# Adaboost is great since we know based on the heatmap above that there are a few features that have a good correlation so we'll be able to utilize the weight of those features properly.
#
# Random forest is good since there is most likely some great interaction effects between features and the subsetting randomforests conducts may be helpful

# %%
from sklearn.metrics import fbeta_score, accuracy_score

from sklearn.ensemble import AdaBoostClassifier as AdaBC, RandomForestClassifier as RF
from sklearn.svm import SVC
import time
def fit_pred_model(model):
#     results=pd.DataFrame()
    results={}
    start=time.time()
    clf=model.fit(X_train,y_train)
    preds=clf.predict(X_test)
    stop=time.time()
    results['model_nm']=type(clf).__name__
    results['model']=clf
    results['accuracy']=accuracy_score(y_test,preds)
    results['fbeta']=fbeta_score(y_test,preds,.5)
    results['time']=stop-start
    model_nm=type(clf).__name__
    print('Fitting Model %s' % model_nm)
    print("the accuracy score is %s" %(accuracy_score(y_test,preds)))
    print("the fbeta score is %s" %(fbeta_score(y_test,preds,.5)))
    print("processing time is %s" %(stop-start))
    
    
    return results


clfcheck=fit_pred_model(l1)
clfcheck
# Out:
# Fitting Model AdaBoostClassifier
# the accuracy score is 0.8581298940580377
# the fbeta score is 0.722188541982419
# processing time is 2.758103609085083
# {'accuracy': 0.8581298940580377,
#  'fbeta': 0.722188541982419,
#  'model': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#            learning_rate=1.0, n_estimators=50, random_state=None),
#  'model_nm': 'AdaBoostClassifier',
#  'time': 2.758103609085083}

# %%
Compile into one dictionary

# %%
ml1=AdaBC()
ml2=SVC()
ml3=RF()
mls=[ml1,ml3]
# def cmp_dict():
#     for i,value in enumerate(mls):
#         exec "clf%s=fit_pred_model(value)" % (i)
class clf_create():
    def __init__(self,models,X, y, sample_size):
        self.models=models
        self.X=X
        self.y=y
        self.sample_size=sample_size
        
#     going to fit and train the models
    def fit_train_models(self):
        for i,v in enumerate(self.models):
            clfd={}
            start_t=time.time()
            clfd['clf']=v.fit(X_train,y_train)
            clfd['clf_nm']=type(clfd['clf']).__name__
            preds=v.predict(X_test)
            clfd['accuracy_score']=accuracy_score(y_test,preds)
            clfd['fbeta']=fbeta_score(y_test, preds,0.5)
            stop_t=time.time()
            clfd['dur']=stop_t-start_t
            setattr(self,"clf%s" %(i),clfd)
            
        return self.__dict__
            
            
            
            
    def get(self):
        return self.__dict__
obj=clf_create(mls, "u", "uu", 10)
obj.fit_train_models()
# Out:
# {'clf0': {'dur': 2.750777006149292, 'accuracy_score': 0.8581298940580377, 'clf_nm': 'AdaBoostClassifier', 'fbeta': 0.722188541982419, 'clf': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)}, 'X': 'u', 'models': [AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None), RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)], 'clf1': {'dur': 0.7950620651245117, 'accuracy_score': 0.8383233532934131, 'clf_nm': 'RandomForestClassifier', 'fbeta': 0.6707317073170731, 'clf': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)}, 'sample_size': 10, 'y': 'uu'}

# %%
clf3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-5a4c5c83abda> in <module>()
# ----> 1 clf3
#       2
#
# NameError: name 'clf3' is not defined

# %%
# lets put everything into a dataframe properly
clfs_pd=pd.DataFrame()
clfs_pd['model_nm']=clfs_results[]

# %%
plot different accuracy scores of each

sns.barplot(x=)
# Out:
#                                          AdaBoostClassifier  \
# accuracy                                            0.85813
# fbeta                                              0.722189
# model     (DecisionTreeClassifier(class_weight=None, cri...
# model_nm                                 AdaBoostClassifier
# time                                                2.74352
#
#                                      RandomForestClassifier  \
# accuracy                                           0.844926
# fbeta                                              0.685358
# model     (DecisionTreeClassifier(class_weight=None, cri...
# model_nm                             RandomForestClassifier
# time                                               0.844948
#
#                                                         SVC
# accuracy                                           0.842776
# fbeta                                              0.686926
# model     SVC(C=1.0, cache_size=200, class_weight=None, ...
# model_nm                                                SVC
# time                                                113.483

# %%
def dict_to_pd(dts):
    df_pd=pd.DataFrame.from_dict(dts[0])
#     for i in dts[1:]:
#         display(i)
#         df_pd=pd.concat(df_pd,pd.aDataFrame.from_dict(i))
    return df_pd
# clf4=dict_to_pd([clf1,clf2,clf3])
dict_to_pd([clf1])
# Out:
#     accuracy     fbeta                                              model  \
# 0   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 1   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 2   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 3   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 4   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 5   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 6   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 7   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 8   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 9   0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 10  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 11  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 12  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 13  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 14  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 15  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 16  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 17  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 18  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 19  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 20  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 21  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 22  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 23  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 24  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 25  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 26  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 27  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 28  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 29  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 30  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 31  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 32  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 33  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 34  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 35  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 36  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 37  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 38  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 39  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 40  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 41  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 42  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 43  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 44  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 45  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 46  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 47  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 48  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
# 49  0.859665  0.724223  DecisionTreeClassifier(class_weight=None, crit...
#
#               model_nm      time
# 0   AdaBoostClassifier  2.736829
# 1   AdaBoostClassifier  2.736829
# 2   AdaBoostClassifier  2.736829
# 3   AdaBoostClassifier  2.736829
# 4   AdaBoostClassifier  2.736829
# 5   AdaBoostClassifier  2.736829
# 6   AdaBoostClassifier  2.736829
# 7   AdaBoostClassifier  2.736829
# 8   AdaBoostClassifier  2.736829
# 9   AdaBoostClassifier  2.736829
# 10  AdaBoostClassifier  2.736829
# 11  AdaBoostClassifier  2.736829
# 12  AdaBoostClassifier  2.736829
# 13  AdaBoostClassifier  2.736829
# 14  AdaBoostClassifier  2.736829
# 15  AdaBoostClassifier  2.736829
# 16  AdaBoostClassifier  2.736829
# 17  AdaBoostClassifier  2.736829
# 18  AdaBoostClassifier  2.736829
# 19  AdaBoostClassifier  2.736829
# 20  AdaBoostClassifier  2.736829
# 21  AdaBoostClassifier  2.736829
# 22  AdaBoostClassifier  2.736829
# 23  AdaBoostClassifier  2.736829
# 24  AdaBoostClassifier  2.736829
# 25  AdaBoostClassifier  2.736829
# 26  AdaBoostClassifier  2.736829
# 27  AdaBoostClassifier  2.736829
# 28  AdaBoostClassifier  2.736829
# 29  AdaBoostClassifier  2.736829
# 30  AdaBoostClassifier  2.736829
# 31  AdaBoostClassifier  2.736829
# 32  AdaBoostClassifier  2.736829
# 33  AdaBoostClassifier  2.736829
# 34  AdaBoostClassifier  2.736829
# 35  AdaBoostClassifier  2.736829
# 36  AdaBoostClassifier  2.736829
# 37  AdaBoostClassifier  2.736829
# 38  AdaBoostClassifier  2.736829
# 39  AdaBoostClassifier  2.736829
# 40  AdaBoostClassifier  2.736829
# 41  AdaBoostClassifier  2.736829
# 42  AdaBoostClassifier  2.736829
# 43  AdaBoostClassifier  2.736829
# 44  AdaBoostClassifier  2.736829
# 45  AdaBoostClassifier  2.736829
# 46  AdaBoostClassifier  2.736829
# 47  AdaBoostClassifier  2.736829
# 48  AdaBoostClassifier  2.736829
# 49  AdaBoostClassifier  2.736829

# %%
# join the three dataframes into one for plotting
clfs=pd.concat([clf1,clf2,clf3], ignore_index=True).drop_duplicates().reset_index(drop=True)
clfs=pd.concat([clf1,clf3], ignore_index=True).drop_duplicates().reset_index(drop=True)
clfs['model_nm']=clfs.model.apply(lambda x : x.__class__.__name__)
# clfs_plt_df=clfs.drop('model',axis=1)
clfs_plt_df=clfs.drop_duplicates()
# clfs_plt_df
# Out:
#                   model_nm                                              model  \
# 0   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 1   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 2   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 3   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 4   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 5   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 6   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 7   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 8   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 9   DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 10  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 11  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 12  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 13  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 14  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 15  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 16  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 17  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 18  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 19  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 20  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 21  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 22  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 23  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 24  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 25  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 26  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 27  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 28  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 29  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 30  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 31  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 32  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 33  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 34  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 35  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 36  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 37  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 38  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 39  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 40  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 41  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 42  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 43  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 44  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 45  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 46  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 47  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 48  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 49  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 50  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 51  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 52  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 53  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 54  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 55  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 56  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 57  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 58  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
# 59  DecisionTreeClassifier  DecisionTreeClassifier(class_weight=None, crit...
#
#     accuracy     fbeta      time
# 0   0.859665  0.724223  2.808612
# 1   0.859665  0.724223  2.808612
# 2   0.859665  0.724223  2.808612
# 3   0.859665  0.724223  2.808612
# 4   0.859665  0.724223  2.808612
# 5   0.859665  0.724223  2.808612
# 6   0.859665  0.724223  2.808612
# 7   0.859665  0.724223  2.808612
# 8   0.859665  0.724223  2.808612
# 9   0.859665  0.724223  2.808612
# 10  0.859665  0.724223  2.808612
# 11  0.859665  0.724223  2.808612
# 12  0.859665  0.724223  2.808612
# 13  0.859665  0.724223  2.808612
# 14  0.859665  0.724223  2.808612
# 15  0.859665  0.724223  2.808612
# 16  0.859665  0.724223  2.808612
# 17  0.859665  0.724223  2.808612
# 18  0.859665  0.724223  2.808612
# 19  0.859665  0.724223  2.808612
# 20  0.859665  0.724223  2.808612
# 21  0.859665  0.724223  2.808612
# 22  0.859665  0.724223  2.808612
# 23  0.859665  0.724223  2.808612
# 24  0.859665  0.724223  2.808612
# 25  0.859665  0.724223  2.808612
# 26  0.859665  0.724223  2.808612
# 27  0.859665  0.724223  2.808612
# 28  0.859665  0.724223  2.808612
# 29  0.859665  0.724223  2.808612
# 30  0.859665  0.724223  2.808612
# 31  0.859665  0.724223  2.808612
# 32  0.859665  0.724223  2.808612
# 33  0.859665  0.724223  2.808612
# 34  0.859665  0.724223  2.808612
# 35  0.859665  0.724223  2.808612
# 36  0.859665  0.724223  2.808612
# 37  0.859665  0.724223  2.808612
# 38  0.859665  0.724223  2.808612
# 39  0.859665  0.724223  2.808612
# 40  0.859665  0.724223  2.808612
# 41  0.859665  0.724223  2.808612
# 42  0.859665  0.724223  2.808612
# 43  0.859665  0.724223  2.808612
# 44  0.859665  0.724223  2.808612
# 45  0.859665  0.724223  2.808612
# 46  0.859665  0.724223  2.808612
# 47  0.859665  0.724223  2.808612
# 48  0.859665  0.724223  2.808612
# 49  0.859665  0.724223  2.808612
# 50  0.841548  0.674975  0.777766
# 51  0.841548  0.674975  0.777766
# 52  0.841548  0.674975  0.777766
# 53  0.841548  0.674975  0.777766
# 54  0.841548  0.674975  0.777766
# 55  0.841548  0.674975  0.777766
# 56  0.841548  0.674975  0.777766
# 57  0.841548  0.674975  0.777766
# 58  0.841548  0.674975  0.777766
# 59  0.841548  0.674975  0.777766

# %%
model=AdaBC()
clf1=model.fit(X_train,y_train)
preds=clf1.predict(X_test)
print(clf1.__class__.__name__)
model=SVC()
clf2=model.fit(X_train,y_train)
print(clf2.__class__.__name__)
# Out:
# AdaBoostClassifier
# SVC

# %%
import seaborn as sns

# %%
sns.set

# %%
import seaborn as sns
sns.set(style='whitegrid')
ax=sns.barplot()

ax = sns.barplot(x="day", y="total_bill", data=tips)
